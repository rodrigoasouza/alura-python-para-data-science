# %% [markdown]
# # Lesson 2
# ## Parameters, Conditionals, and Type Conversion

# %%
def apply_for_drivers_license():
  old = input('How old are you? ')
  old = int(old)

  if old >= 15 :
    print('Can apply')
  else :
    print('Can\'t apply')

# %%
apply_for_drivers_license()
# Out:
# How old are you?33
# Can apply

# %% [markdown]
# ### Going to the bakery
# #### Velocity formula
# speed = distance ÷ time
#
# [https://science.howstuffworks.com/math-concepts/velocity-formula.htm]
# ![image.png](data:image/png;base64,...)

# %%
def calc_speed(distance, time):
 speed = distance / time
 print(f'Speed: {speed} m/s')

# %%
calc_speed(100, 20)
# Out:
# Speed: 5.0 m/s
